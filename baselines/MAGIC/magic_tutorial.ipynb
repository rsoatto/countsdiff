# %% [markdown]
# Modified tutorial for MAGIC wrapper.

# %%
# !pip install --user magic-impute

# %% [markdown]
# Will require pandas 2.0.3 which is incompatible with anndata

# %%
import magic
import scprep

import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

# Matplotlib command for Jupyter notebooks only
# %matplotlib inline

# %%
import os
print(os.getcwd())

# %%
os.chdir("..")

# %%
# %load_ext autoreload
# %autoreload 2
from scIDPMs.data_utils import SingleCellDataset
from MAGIC.magic_wrapper import MAGICWrapper

# %%
scdataset = SingleCellDataset("../src/countsdiff/data/filtered_hca_data.hdf5", "test")

# %%
wrap = MAGICWrapper()

# %% [markdown]
# changed dataloader in scIDPM version to also include true_mask as missingness_mask, observed_mask as valid_mask, and gt_mask as the mask fed to the model, which is a subset of observed_mask. Hence, impute_mask is observed but missing in gt_mask

# %%
# impute_mask is not missing and not given to model

impute_mask = scdataset.observed_mask * ~scdataset.gt_mask

# %%
imputed_data = wrap.impute_data(scdataset.counts, impute_mask, scdataset.gene_names, scdataset.observed_mask)

# %%
imputed_data.sum()

# %%
pd.DataFrame(scdataset.counts).sum()
